# %%
import pandas as pd

# %%
frame = pd.read_csv("final_merged.csv")

# %%
from pymongo import MongoClient

# %%
connection_string = "mongodb://localhost:27017"

# %%
client= MongoClient(connection_string)

# %%
client.list_database_names()
# Out:
# ['admin', 'catalogue', 'config', 'dheerajgajula', 'local', 'test']

# %%
test = client['test']
test_collection = test['tst']

# %%
val = test_collection.find({"user_id":"A3HFQE02MDPC6I"})

# %%
for n in val:
    print(type(n))

# %%
len(val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(val)
#
# NameError: name 'val' is not defined

# %%
for cols in frame.index:
    for cols in frame.index:
        present = user_list.find_one({"_id":frame['user_id'][cols]})
        if present == None:
            document = {
                "_id":frame['user_id'][cols],
                "product_id":[frame['product_id'][cols]],
                "rating":[frame['rating'][cols]]
            }
            inserted = user_list.insert_one(document).acknowledged
        else:
            products = present['product_id']
            ratings = present['rating']
            products.append(frame['product_id'][cols])
            ratings.append(frame['rating'][cols])
            updated_query = {"$set" : {"product_id":products, 'rating':ratings}}

# %%
val = test_collection.find({"user_id":"A3HFQE02MDPC6I"})
dict_array=[]
for n in val:
    dict_array.append(n)

# %%
dict_array[0], dict_array[1]
# Out:
# ({'_id': ObjectId('64e211b7d41ea940f2adcd37'),
#   'product_id': 'B013VNVFMO',
#   'user_id': 'A3HFQE02MDPC6I',
#   'rating': 5.0},
#  {'_id': ObjectId('64e211b7d41ea940f2ade38a'),
#   'product_id': 'B016J9EQNW',
#   'user_id': 'A3HFQE02MDPC6I',
#   'rating': 5.0})

# %%
json_arr = []
for dics in dict_array:
    temp = {"product_id": dics["product_id"], "rating": dics["rating"]}
    json_arr.append(temp)

# %%
import json
final_json = json.dumps(json_arr, indent=1)

# %%
print(final_json)
# Out:
# [
#  {
#   "product_id": "B013VNVFMO",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B016J9EQNW",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B01B5GTUM6",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B01DGWYQCG",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B01GQ12URM",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B004FK7R02",
#   "rating": 4.0
#  },
#  {
#   "product_id": "B01A9G31QE",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B01EHXOUYM",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B01CC7GT1C",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B016OLM9DO",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B00BO5I5RA",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B00DCIZJ5S",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B00HPR77B6",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B00JTU2OAG",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B00K00RIBY",
#   "rating": 5.0
#  },
#  {
#   "product_id": "B00LDYSPAY",
#   "rating": 5.0
#  },
#  {
# ...

# %%
import requests

val = requests.get("https://8a0c-203-192-244-175.ngrok.io/order_list", params={"user_id": "A3HFQE02MDPC6I"})

# %%
val
# Out:
# <Response [200]>

# %%
val.json()
# Out:
# '[{"product_id": "B013VNVFMO", "rating": 5.0}, {"product_id": "B016J9EQNW", "rating": 5.0}, {"product_id": "B01B5GTUM6", "rating": 5.0}, {"product_id": "B01DGWYQCG", "rating": 5.0}, {"product_id": "B01GQ12URM", "rating": 5.0}, {"product_id": "B004FK7R02", "rating": 4.0}, {"product_id": "B01A9G31QE", "rating": 5.0}, {"product_id": "B01EHXOUYM", "rating": 5.0}, {"product_id": "B01CC7GT1C", "rating": 5.0}, {"product_id": "B016OLM9DO", "rating": 5.0}, {"product_id": "B00BO5I5RA", "rating": 5.0}, {"product_id": "B00DCIZJ5S", "rating": 5.0}, {"product_id": "B00HPR77B6", "rating": 5.0}, {"product_id": "B00JTU2OAG", "rating": 5.0}, {"product_id": "B00K00RIBY", "rating": 5.0}, {"product_id": "B00LDYSPAY", "rating": 5.0}, {"product_id": "B00LOZ7WCO", "rating": 5.0}, {"product_id": "B00M0DGBRQ", "rating": 4.0}, {"product_id": "B00MAWQFZ0", "rating": 5.0}, {"product_id": "B00MAWRN5Q", "rating": 5.0}, {"product_id": "B00MAWQVZY", "rating": 5.0}, {"product_id": "B00MAWRT0A", "rating": 5.0}, {"prod
# ...

# %%
max_orders_dict = max(dict_array, key=lambda x: x["rating"])

print(max_orders_dict)
# Out:
# {'_id': ObjectId('64e211b7d41ea940f2adcd37'), 'product_id': 'B013VNVFMO', 'user_id': 'A3HFQE02MDPC6I', 'rating': 5.0}

# %%
import requests

val = requests.get("http://127.0.0.1:8000/high_rating", params={"user_id": "A3HFQE02MDPC6I"})

# %%
val
# Out:
# <Response [200]>

# %%
val.json()
# Out:
# {'product_id': 'B013VNVFMO', 'rating': 5.0}

# %%
from pymongo import MongoClient
connection_string = "mongodb://localhost:27017/"
client = MongoClient(connection_string)
client.list_database_names()
# Out:
# ['admin', 'catalogue', 'config', 'dheerajgajula', 'local', 'test']

# %%
database= client['test']
meta_data = database.meta_data

# %%
id = "7178680776"
val = meta_data.find({"asin":id})

# %%
id = "7178680776"
val = meta_data.find({"asin":id})
print(type(val))
for i in val:
    print(i)
    print(type(i))
    vm = i['also_buy']
    print(vm)
# Out:
# <class 'pymongo.cursor.Cursor'>
# ...

# %%
vm
# Out:
# ['B01E7LCSL6', 'B008X5RVME']

# %%
id = "B0006O10P4"
val = meta_data.find({"asin": id})
for i in val:
    print(i)
    print(i['title'],i['main_cat'],i['price'])
# Out:
# {'_id': ObjectId('64e261a0270728d3408193a8'), 'category': [], 'tech1': '', 'description': ['We bring you this all-natural, luxury Zum bar featuring Anise Lavender, hand-crafted by leading maker Indigo Wild.<br><br>The sweet, calming licorice-like aroma of anise is combined with the soothing cleansing properties of lavender. Anise is said to melt away general soreness; lavender provides gentle but effective pore-cleansing for both body and face.<br><br>Weight: 3 oz.<br><br>Indigo Wild is famous for its Zum Bar, a goat milk based soap. Indigo Wild chooses goat milk because it is naturally homogenized and has naturally occurring triglycerides (good fats). This results in the soap pH being nearly identical to our own skin and therefore less harsh than most commercial soaps.<br><br>Indigo Wild is focused on producing and distributing high quality, handmade, all natural goods. All natural raw materials make up each product. The essential oils used to add scent to Indigo Wild products conta
# ...

# %%
anther_string="mongodb+srv://dheerajgajula2209:dheeraj@cluster0.akjrg3v.mongodb.net/"

# %%
client_meta = MongoClient(anther_string)

# %%
client_meta.list_database_names()
# Out:
# ['test', 'admin', 'local']
